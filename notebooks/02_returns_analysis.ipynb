# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from src.data_loader import get_prices
from src.features import calculate_returns, normalize
from src.plotting import plot_data

tickers = ["AAPL", "TSLA", "SPY"]
prices = get_prices(tickers)

returns = calculate_returns(prices)
normalized = normalize(prices)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
plot_data(normalized, "Normalized Prices")
plot_data(returns, "Daily Returns", ylabel="Returns")

# %%
from src.analysis import calculate_volatility

vol = calculate_volatility(returns)
vol
# Out:
# Ticker
# AAPL    0.021146
# SPY     0.014254
# TSLA    0.042902
# dtype: float64
