# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from src.data_loader import get_prices

tickers = ["AAPL", "TSLA", "SPY"]
prices = get_prices(tickers)

prices.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
# Ticker           AAPL         SPY       TSLA
# Date
# 2020-01-02  72.400505  296.888092  28.684000
# 2020-01-03  71.696640  294.640076  29.534000
# 2020-01-06  72.267952  295.764160  30.102667
# 2020-01-07  71.928070  294.932495  31.270666
# 2020-01-08  73.085106  296.504425  32.809334

# %%
from src.plotting import plot_data

plot_data(prices, "Raw Stock Prices")
