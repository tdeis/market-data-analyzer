# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
from src.data_loader import get_prices
from src.features import calculate_returns
from src.analysis import calculate_correlation

tickers = ["AAPL", "TSLA", "SPY"]
prices = get_prices(tickers)

returns = calculate_returns(prices)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
corr = calculate_correlation(returns)
corr
# Out:
# Ticker      AAPL       SPY      TSLA
# Ticker
# AAPL    1.000000  0.815805  0.510815
# SPY     0.815805  1.000000  0.515201
# TSLA    0.510815  0.515201  1.000000
